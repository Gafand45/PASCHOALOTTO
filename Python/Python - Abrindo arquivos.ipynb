# %% [markdown]
# CSV - Acessando arquivos com Pandas

# %%
import pandas as pd

csv_tele = pd.read_csv(r'C:\Users\uSeR\OneDrive\01 - GitHub\PROJETO PASCHOALOTTO\PASCHOALOTTO\Dataset\telemarketing_atendimento.csv',sep=',')

display(csv_tele.head(10))
# Out:
#    ID_Atendimento     Data_Atendimento Tipo_Atendimento       Status  \
# 0               1  2023-10-25 18:32:57  Suporte Técnico    Resolvido
# 1               2  2023-04-21 23:10:29  Suporte Técnico     Pendente
# 2               3  2023-03-02 12:47:03       Informação  Sem Solução
# 3               4  2024-08-25 21:27:16  Suporte Técnico     Pendente
# 4               5  2024-01-11 01:49:56       Reclamação  Sem Solução
# 5               6  2023-02-01 07:35:49       Reclamação  Sem Solução
# 6               7  2023-02-11 08:42:57       Informação    Resolvido
# 7               8  2023-08-22 06:38:53       Reclamação     Pendente
# 8               9  2024-04-08 16:35:13     Cancelamento  Encaminhado
# 9              10  2023-11-30 20:14:10     Cancelamento     Pendente
#
#   Meio_Contato  Tempo_Resolucao_minutos  Avaliacao
# 0     Telefone                     28.0        5.0
# 1  Chat Online                     16.0        2.0
# 2     WhatsApp                      2.0        NaN
# ...

# %% [markdown]
# EXCEL - Acessando arquivos com Pandas

# %%
import pandas as pd

excel_tele = pd.read_excel(r'C:\Users\uSeR\OneDrive\01 - GitHub\PROJETO PASCHOALOTTO\PASCHOALOTTO\Dataset\telemarketing_atendimento.xlsx')

display(excel_tele.tail(10))
# Out:
#        ID_Atendimento     Data_Atendimento Tipo_Atendimento       Status  \
# 14990           14991  2023-06-22 18:27:17           Vendas     Pendente
# 14991           14992  2024-05-10 15:38:09       Reclamação     Pendente
# 14992           14993  2024-07-05 07:37:27  Suporte Técnico    Resolvido
# 14993           14994  2023-09-21 14:18:34       Informação  Sem Solução
# 14994           14995  2023-09-06 05:44:24           Vendas     Pendente
# 14995           14996  2024-08-23 19:52:06       Reclamação     Pendente
# 14996           14997  2023-01-06 07:54:13     Cancelamento    Resolvido
# 14997           14998  2024-04-30 05:48:12     Cancelamento  Encaminhado
# 14998           14999  2023-06-11 08:43:33     Cancelamento    Resolvido
# 14999           15000  2023-05-12 02:21:33       Informação    Resolvido
#
#       Meio_Contato  Tempo_Resolucao_minutos  Avaliacao
# 14990       E-mail                     50.0        NaN
# ...

# %% [markdown]
# JSON - Acessando arquivos com Pandas

# %%
import pandas as pd
json_tele = pd.read_json(r'C:\Users\uSeR\OneDrive\01 - GitHub\PROJETO PASCHOALOTTO\PASCHOALOTTO\Dataset\telemarketing_atendimento.json')

display(json_tele.head(10))
# Out:
#    ID_Atendimento     Data_Atendimento Tipo_Atendimento       Status  \
# 0               1  2023-10-25 18:32:57  Suporte Técnico    Resolvido
# 1               2  2023-04-21 23:10:29  Suporte Técnico     Pendente
# 2               3  2023-03-02 12:47:03       Informação  Sem Solução
# 3               4  2024-08-25 21:27:16  Suporte Técnico     Pendente
# 4               5  2024-01-11 01:49:56       Reclamação  Sem Solução
# 5               6  2023-02-01 07:35:49       Reclamação  Sem Solução
# 6               7  2023-02-11 08:42:57       Informação    Resolvido
# 7               8  2023-08-22 06:38:53       Reclamação     Pendente
# 8               9  2024-04-08 16:35:13     Cancelamento  Encaminhado
# 9              10  2023-11-30 20:14:10     Cancelamento     Pendente
#
#   Meio_Contato  Tempo_Resolucao_minutos  Avaliacao
# 0     Telefone                     28.0        5.0
# 1  Chat Online                     16.0        2.0
# 2     WhatsApp                      2.0        NaN
# ...
